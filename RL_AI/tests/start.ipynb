# %%
#dotnet 설치
# !if ! command -v $HOME/.dotnet/dotnet >/dev/null 2>&1 && ! command -v dotnet >/dev/null 2>&1; then \
  curl -fsSL https://dot.net/v1/dotnet-install.sh -o ~/dotnet-install.sh && \
  bash ~/dotnet-install.sh --channel 10.0 --install-dir $HOME/.dotnet; \
fi
# !if command -v dotnet >/dev/null 2>&1; then dotnet --info; else $HOME/.dotnet/dotnet --info; fi
# Out:
# =.NET SDK:
#  Version:           10.0.201
#  Commit:            4d3023de60
#  Workload version:  10.0.200-manifests.0793c108
#  MSBuild version:   18.3.0-release-26153-122+4d3023de6
#
# 런타임 환경:
#  OS Name:     ubuntu
#  OS Version:  24.04
#  OS Platform: Linux
#  RID:         linux-x64
#  Base Path:   /home/20212052/.dotnet/sdk/10.0.201/
#
# 설치된 .NET 워크로드:
# 표시할 설치된 워크로드가 없습니다.
# 새 매니페스트를 설치할 때 use workload sets 사용하도록 구성됩니다.
# 워크로드 집합이 설치되어 있지 않습니다. "dotnet workload restore"를 실행하여 워크로드 집합을 설치하세요.
#
# Host:
#   Version:      10.0.5
#   Architecture: x64
#   Commit:       a612c2a105
#
# .NET SDKs installed:
#   10.0.201 [/home/20212052/.dotnet/sdk]
#
# .NET runtimes installed:
#   Microsoft.AspNetCore.App 10.0.5 [/home/20212052/.dotnet/shared/Microsoft.AspNetCore.App]
#   Microsoft.NETCore.App 10.0.5 [/home/20212052/.dotnet/shared/Microsoft.NETCore.App]
#
# Other architectures found:
#   None
#
# Environment variables:
#   Not set
#
# global.json file:
#   Not found
#
# Learn more:
# ...

# %%
#노트북 커널 기준 패키지 확인 / 설치
import importlib.util
import subprocess
import sys

required = ["torch", "numpy", "pytest"]
missing = [pkg for pkg in required if importlib.util.find_spec(pkg) is None]

if missing:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-I", *missing])

import torch
import numpy
import setuptools

print(sys.executable)
print(torch.__version__)
print(numpy.__version__)
print(setuptools.__version__)
print(torch.cuda.is_available())
# Out:
# /opt/python/bin/python
# 2.11.0+cu130
# 2.3.5
# 82.0.0
# True

# %%
#압축 해제
# !bash -lc 'ZIP_PATH=""; if [ -f RL_AI.zip ]; then ZIP_PATH=RL_AI.zip; elif [ -f ~/RL_AI.zip ]; then ZIP_PATH=~/RL_AI.zip; fi; if [ -n "$ZIP_PATH" ] && [ ! -d ~/RL_AI ]; then mkdir -p ~/RL_AI && unzip -oq "$ZIP_PATH" -d ~/RL_AI >/dev/null; fi; if [ -d ~/RL_AI ]; then echo "RL_AI ready"; elif [ -n "$ZIP_PATH" ]; then echo "RL_AI unzip skipped/failed"; else echo "RL_AI.zip not found, skipping unzip"; fi'
# Out:
# /etc/profile.d/http.proxy.sh: line 30: syntax error near unexpected token `fi'
# /etc/profile.d/http.proxy.sh: line 30: `fi'
# ...
#  파이썬은 3.12 버전이 설치 되어 있습니다.
#  다음의 명령어에 따라서 실행되는 파이썬의 버전이 다릅니다.
#
#  python
#    이 노트북의 파이썬 가상환경의 python 3.12 버전이 실행됩니다.
#    사전 설치된 모든 패키지가 사용가능합니다.
#    패키지 추가 설치는 가상 환경을 생성하거나,
#    pip install -I <PACKAGE> 와 같이 사용해주세요.
#
#   -------------- 파이썬 가상환경 목록 -----------------
#     3.12		Data-Science Packages
#     3.12-cuda12.9
#     pytorch-2.10.0-cuda12.9-py3.12
#   --------------------------------------------------
#
#     다음과 같이 실행하여 가상환경을 변경할 수 있습니다.
#     pyenv [가상환경이름]
#
#  /usr/bin/python3.12
#    python 3.12 버전이 실행됩니다. Ubuntu 24.04 의 시스템에서 필요합니다.
# ...
#
# /etc/profile.d/pytorch_2.10.0-cu129.sh: line 7: syntax error near unexpected token `fi'
# /etc/profile.d/pytorch_2.10.0-cu129.sh: line 7: `  fi'
# [ 데이터셋 안내 : /home/20212052/Datasets ]
#
# ANTI_UAV_RGBT : A Large-Scale Benchmark for Vision-based UAV Tracking
# CUB_200_2011 : 인공지능최신기술 CUB 데이터셋
# ...

# %%
#C# 빌드
# !bash -lc 'if command -v dotnet >/dev/null 2>&1; then DOTNET_CMD=$(command -v dotnet); else DOTNET_CMD=$HOME/.dotnet/dotnet; fi; $DOTNET_CMD build ~/RL_AI/SeaEngine/csharp/SeaEngineCli/SeaEngineCli.csproj -c Debug -v q >/dev/null && echo "SeaEngineCli build ok"'
# Out:
# /etc/profile.d/http.proxy.sh: line 30: syntax error near unexpected token `fi'
# /etc/profile.d/http.proxy.sh: line 30: `fi'
# ...
#  파이썬은 3.12 버전이 설치 되어 있습니다.
#  다음의 명령어에 따라서 실행되는 파이썬의 버전이 다릅니다.
#
#  python
#    이 노트북의 파이썬 가상환경의 python 3.12 버전이 실행됩니다.
#    사전 설치된 모든 패키지가 사용가능합니다.
#    패키지 추가 설치는 가상 환경을 생성하거나,
#    pip install -I <PACKAGE> 와 같이 사용해주세요.
#
#   -------------- 파이썬 가상환경 목록 -----------------
#     3.12		Data-Science Packages
#     3.12-cuda12.9
#     pytorch-2.10.0-cuda12.9-py3.12
#   --------------------------------------------------
#
#     다음과 같이 실행하여 가상환경을 변경할 수 있습니다.
#     pyenv [가상환경이름]
#
#  /usr/bin/python3.12
#    python 3.12 버전이 실행됩니다. Ubuntu 24.04 의 시스템에서 필요합니다.
# ...
#
# /etc/profile.d/pytorch_2.10.0-cu129.sh: line 7: syntax error near unexpected token `fi'
# /etc/profile.d/pytorch_2.10.0-cu129.sh: line 7: `  fi'
# [ 데이터셋 안내 : /home/20212052/Datasets ]
#
# ANTI_UAV_RGBT : A Large-Scale Benchmark for Vision-based UAV Tracking
# CUB_200_2011 : 인공지능최신기술 CUB 데이터셋
# ...

# %%
#평가 / 학습
import os
import sys
from pathlib import Path
from shutil import which

home = Path.home()
if str(home) not in sys.path:
    sys.path.insert(0, str(home))

dotnet_cmd = which("dotnet")
if dotnet_cmd is None:
    fallback = home / ".dotnet" / ("dotnet.exe" if os.name == "nt" else "dotnet")
    if fallback.exists():
        dotnet_cmd = str(fallback)
if dotnet_cmd:
    os.environ["DOTNET_CMD"] = dotnet_cmd

from RL_AI.SeaEngine.agents import (
    SeaEngineRandomAgent,
    SeaEngineGreedyAgent,
    SeaEngineRLAgent,
)
from RL_AI.SeaEngine.evaluator import evaluate_agents
from RL_AI.SeaEngine.trainer import SeaEnginePPOTrainer


EVAL_MATCHES = 100
MAX_TURNS = 100
TRAIN_EPISODES = 300
UPDATE_INTERVAL = 8


def run_eval(label, p1_agent, p2_agent, *, num_matches=EVAL_MATCHES, max_turns=MAX_TURNS):
    print(f"\n=== {label} ===")
    summary = evaluate_agents(
        p1_agent,
        p2_agent,
        num_matches=num_matches,
        max_turns=max_turns,
    )
    print(f"report: {summary['report_path']}")
    print(
        f"result: P1 wins={summary['p1_wins']}, "
        f"P2 wins={summary['p2_wins']}, "
        f"draws={summary['draws']}"
    )
    return summary


# 1. baseline 확인: Random vs Greedy
baseline_summary = run_eval(
    "Baseline: Random vs Greedy",
    SeaEngineRandomAgent(seed=1),
    SeaEngineGreedyAgent(seed=2),
)

# 2. mixed opponent 학습
print("\n=== Training: RL with mixed opponents (Random + Greedy) ===")
agent = SeaEngineRLAgent(seed=1)
trainer = SeaEnginePPOTrainer(agent)
pool = trainer.build_default_opponent_pool(seed=7)
train_summary = trainer.train(
    num_episodes=TRAIN_EPISODES,
    opponent_pool=pool,
    max_turns=MAX_TURNS,
    update_interval=UPDATE_INTERVAL,
)
print(train_summary)

# 3. 학습 후 평가: RL vs Random
rl_vs_random_summary = run_eval(
    "Post-train: RL vs Random",
    agent,
    SeaEngineRandomAgent(seed=3),
)

# 4. 학습 후 평가: RL vs Greedy
rl_vs_greedy_summary = run_eval(
    "Post-train: RL vs Greedy",
    agent,
    SeaEngineGreedyAgent(seed=4),
)
# Out:
# === Baseline: Random vs Greedy ===
# report: /home/20212052/RL_AI/log/seaengine_evaluation_report_20260408_183745.txt
# result: P1 wins=12, P2 wins=88, draws=0
#
# === Training: RL with mixed opponents (Random + Greedy) ===
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# Cell In[5], line 63
#      59 print("\n=== Training: RL with mixed opponents (Random + Greedy) ===")
#      60 agent = SeaEngineRLAgent(seed=1)
#      61 trainer = SeaEnginePPOTrainer(agent)
#      62 pool = trainer.build_default_opponent_pool(seed=7)
# ---> 63 train_summary = trainer.train(
#      64     num_episodes=TRAIN_EPISODES,
#      65     opponent_pool=pool,
#      66     max_turns=MAX_TURNS,
#
# File ~/RL_AI/SeaEngine/trainer.py:205, in SeaEnginePPOTrainer.train(self, num_episodes, opponent_agent, opponent_pool, card_data_path, player1_deck, player2_deck, max_turns, update_interval)
# ...
